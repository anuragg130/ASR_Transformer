# %%
! pip list
# Out:
# Package                      Version
# ---------------------------- ------------
# absl-py                      1.2.0
# appdirs                      1.4.4
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        22.1.0
# audioread                    3.0.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       5.0.1
# cachetools                   5.2.0
# certifi                      2022.6.15
# cffi                         1.15.1
# charset-normalizer           2.1.0
# click                        8.1.3
# colorama                     0.4.5
# comtypes                     1.1.14
# contourpy                    1.0.7
# cuda-python                  12.1.0
# cycler                       0.11.0
# Cython                       0.29.34
# debugpy                      1.6.2
# decorator                    5.1.1
# ...
